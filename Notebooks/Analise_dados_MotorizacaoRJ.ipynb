# %%
import pandas as pd 
import numpy as np 
import matplotlib as plt

# %%
data2 = pd.read_csv("C:\\Users\\wesle\\Documents\\dados\\taxa_motorizacao.csv", sep=",")
dt_clean = data2.dropna()
dt_rj2 = data2.loc[(data2['sigla_uf'] == "RJ")]
data2.info()
display(dt_rj2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 486 entries, 0 to 485
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ano               486 non-null    int64
#  1   sigla_uf          486 non-null    object
#  2   id_municipio      486 non-null    int64
#  3   taxa_motorizacao  486 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 15.3+ KB
#       ano sigla_uf  id_municipio  taxa_motorizacao
# 21   2001       RJ       3304557        226.995236
# 48   2002       RJ       3304557        237.130201
# 75   2003       RJ       3304557        244.065991
# 102  2004       RJ       3304557        248.274490
# 129  2005       RJ       3304557        254.319898
# 156  2006       RJ       3304557        261.043807
# 183  2007       RJ       3304557        275.907726
# 210  2008       RJ       3304557        287.607285
# 237  2009       RJ       3304557        303.080636
# ...

# %%
data4 = pd.read_csv("C:\\Users\\wesle\\Documents\\dados\\emissao_co2_material_particulado.csv", sep=",")
data4.info()
dt_clean = data2.dropna()
dt_rj4 = data4.loc[(data4['sigla_uf'] == "RJ")]
display(dt_rj4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ano           324 non-null    int64
#  1   sigla_uf      324 non-null    object
#  2   id_municipio  324 non-null    int64
#  3   emissao_co2   324 non-null    int64
#  4   emissao_mp    324 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 12.8+ KB
#       ano sigla_uf  id_municipio  emissao_co2  emissao_mp
# 21   2007       RJ       3304557          536         124
# 48   2008       RJ       3304557          521         117
# 75   2009       RJ       3304557          514         108
# 102  2010       RJ       3304557          574         113
# 129  2011       RJ       3304557          665         120
# 156  2012       RJ       3304557          701         112
# 183  2013       RJ       3304557          673          96
# ...

# %%
data6 = pd.read_csv("C:\\Users\\wesle\\Documents\\dados\\municipio_tipo.csv", sep=",")
data6.info()
dt_clean = data6.dropna()
dt_rj6 =dt_clean.loc[(dt_clean['id_municipio'] ==3304557)]
dados = dt_rj6.drop(columns=["outros","bonde", "utilitario"])
display(dados)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149396 entries, 0 to 1149395
# Data columns (total 26 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   sigla_uf          1149396 non-null  object
#  1   id_municipio      1149396 non-null  int64
#  2   ano               1149396 non-null  int64
#  3   mes               1149396 non-null  int64
#  4   automovel         1149396 non-null  int64
#  5   bonde             1149396 non-null  int64
#  6   caminhao          1149396 non-null  int64
#  7   caminhaotrator    1149396 non-null  int64
#  8   caminhonete       1149396 non-null  int64
#  9   camioneta         1149396 non-null  int64
#  10  ciclomotor        1149396 non-null  int64
#  11  microonibus       1149396 non-null  int64
#  12  motocicleta       1149396 non-null  int64
#  13  motoneta          1149396 non-null  int64
#  14  onibus            1149396 non-null  int64
# ...

# %%
data = pd.read_excel('C:\\Users\\wesle\\Documents\\dados\\data_motorizacao_rj.xlsx')
data.info()
display(data)

# %%
Analise de indicadores economicos, educacionais e sociais

O objetivo desta trilha  ́e entender como os diferentes indicadores econˆomicos,
educacionais e sociais se relacionam entre si, e entender como determinada tendˆencia
econˆomica de determinada regi ̃ao influencia indicadores educacionais. Assim como na
trilha anterior, fica a cargo do candidato se ele deseja se ater a um contexto espec ́ıfico
(determinado munic ́ıpio, estado, etc..) ou a todo o pa ́ıs.

# %%
Analise do contexto polıtico brasileiro

O objetivo desta trilha e produzir uma analise acerca das tendencias polıticas
brasileiras com o auxılio de dados hist ́oricos das elei ̧c ̃oes realizadas anteriormente. A
an ́alise pode se ater a uma esfera espec ́ıfica (ex. resultados de elei ̧c ̃oes no municıpio
do Rio de Janeiro), assim como avaliar a esfera mais geral (contexto pol ́ıtico do Brasil
inteiro).
